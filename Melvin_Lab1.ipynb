# %% [markdown]
# # Most Popular Methods of Stealing Data

# %% [markdown]
# #### This visualization is intended for business leaders deciding what security threats they should be most worried about when determining how to improve network security.

# %% [markdown]
# 2017 table will be the only table used.

# %% [markdown]
# #### Using any document editor or ETL tool of your choice (I used LibreOffice), Eliminate all columns except Year and Method of leak.

# %%
from IPython.core.display import Image 
Image(filename='/Users/melvinchow/Desktop/cleaned.png')

# %% [markdown]
# #### Convert current "Year" values to their actual years

# %%
from IPython.core.display import Image 
Image(filename='/Users/melvinchow/Desktop/cleaned2.png')

# %% [markdown]
# #### Open Tableau.  Connect with excel sheet.  Drag and drop 2017 sheet to right side.

# %%
from IPython.core.display import Image 
Image(filename='/Users/melvinchow/Desktop/tab1.png')

# %% [markdown]
# #### Click on "Sheet 1" tab on bottom left. Year is by default read as number.  We need it to be read as a date/time dimension.  Right click under "Dimensions" window and click "Create calculated field".  Enter the following formula:

# %%
from IPython.core.display import Image 
Image(filename='/Users/melvinchow/Desktop/tab2.png')

# %%
from IPython.core.display import Image 
Image(filename='/Users/melvinchow/Desktop/tab3.png')

# %% [markdown]
# #### This creates a new dimension where the values in "Year" are interpreted as a date/time value rather than a number.

# %% [markdown]
# #### Using Year dimension and sum of records categorized by Method of Leaks, this is the chart I produced:

# %%
from IPython.core.display import Image 
Image(filename='/Users/melvinchow/Desktop/final.png')

# %% [markdown]
# ### From this chart we can see that "lost/stolen devices" were formerly the primary way for thieves to steal data, but over many years hacking has become the dominant method.  All businesses today should invest in firewalls and more robust remote network connection protocols to safeguard data from remote hackers.
